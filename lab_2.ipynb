# %% [markdown]
# <a href="https://colab.research.google.com/github/sarafonseca0125-bit/tareaprogramacion/blob/main/lab_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !g++ --version
# Out:
# g++ (Ubuntu 11.4.0-1ubuntu1~22.04.2) 11.4.0
# Copyright (C) 2021 Free Software Foundation, Inc.
# This is free software; see the source for copying conditions.  There is NO
# warranty; not even for MERCHANTABILITY or FITNESS FOR A PARTICULAR PURPOSE.

# %%
# !gcc --version
# Out:
# gcc (Ubuntu 11.4.0-1ubuntu1~22.04.2) 11.4.0
# Copyright (C) 2021 Free Software Foundation, Inc.
# This is free software; see the source for copying conditions.  There is NO
# warranty; not even for MERCHANTABILITY or FITNESS FOR A PARTICULAR PURPOSE.

# %%
# %%shell
# g++ --version
# Out:
# g++ (Ubuntu 11.4.0-1ubuntu1~22.04.2) 11.4.0
# Copyright (C) 2021 Free Software Foundation, Inc.
# This is free software; see the source for copying conditions.  There is NO
# warranty; not even for MERCHANTABILITY or FITNESS FOR A PARTICULAR PURPOSE.

# %%
# %%writefile brr.cpp
#
# #include <iostream>
# using namespace std;
# int main() {
# int edad = 18;
# float promedio = 4.5;
# char letra = 'a';
# bool aprobado = true;
#
# cout << "edad: " << edad << endl;
# cout << "promedio: " << promedio << endl;
# cout << "letra: " << letra << endl;
# cout << "aprobado: " << aprobado << endl;
# return 0;
# }
# Out:
# Overwriting brr.cpp

# %%
# !g++ brr.cpp -o brr

# %%
# !./brr
# Out:
# edad: 18
# promedio: 4.5
# letra: a
# aprobado: 1

# %%
# %%writefile br.cpp
# #include <iostream>
# using namespace std;
#
# int main() {
#     int a = 10, b = 8 ;
#
#     cout << "suma: " << a + b << endl;
#     cout << "resta: " << a - b << endl;
#     cout << "multiplicacion: " << a * b << endl;
#     cout << "division: " << a / b << endl;
#     return 0;
# }
# Out:
# Overwriting br.cpp

# %%
# !g++ br.cpp -o br

# %%
# !./br
# Out:
# suma: 18
# resta: 2
# multiplicacion: 80
# division: 1

# %%
# %%writefile brrr.cpp
# #include <iostream>
# using namespace std;
# int main() {
#     int a = 10, b = 8 ;
#     if (a > b)
#         cout << "a es mayor que b" << endl;
#     else cout << "a es menor que b" << endl;
#     return 0;
# }
# Out:
# Writing brrr.cpp

# %%
# !g++ brrr.cpp -o brrr

# %%
# !./brrr
# Out:
# a es mayor que b

# %%
# %%writefile brrrr.cpp
# #include <iostream>
# using namespace std;
