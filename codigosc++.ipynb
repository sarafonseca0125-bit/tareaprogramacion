# %% [markdown]
# <a href="https://colab.research.google.com/github/sarafonseca0125-bit/tareaprogramacion/blob/main/codigosc%2B%2B.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !g++ --version
# Out:
# g++ (Ubuntu 11.4.0-1ubuntu1~22.04.2) 11.4.0
# Copyright (C) 2021 Free Software Foundation, Inc.
# This is free software; see the source for copying conditions.  There is NO
# warranty; not even for MERCHANTABILITY or FITNESS FOR A PARTICULAR PURPOSE.

# %%
# !gcc --version
# Out:
# gcc (Ubuntu 11.4.0-1ubuntu1~22.04.2) 11.4.0
# Copyright (C) 2021 Free Software Foundation, Inc.
# This is free software; see the source for copying conditions.  There is NO
# warranty; not even for MERCHANTABILITY or FITNESS FOR A PARTICULAR PURPOSE.

# %%
# %%shell
# g++ --version
# Out:
# g++ (Ubuntu 11.4.0-1ubuntu1~22.04.2) 11.4.0
# Copyright (C) 2021 Free Software Foundation, Inc.
# This is free software; see the source for copying conditions.  There is NO
# warranty; not even for MERCHANTABILITY or FITNESS FOR A PARTICULAR PURPOSE.

# %%
# %%writefile la_cabra.cpp
# #include <iostream>
# int main(){
#   std::cout << "La cabra" << std::endl;
#   return 0;
# }
# Out:
# Overwriting la_cabra.cpp

# %%
# !g++ la_cabra.cpp -o la_cabra

# %%
# !./la_cabra
# Out:
# La cabra

# %%
# %%writefile suma.cpp
# #include <iostream>
# int main(){
#     int a = 4;
#   int b = 2;
#   int c = 8;
#     int prom = (a+b+c)/3;
#     std::cout << "El promedio es: " << prom << std::endl;
#     return 0;
#     }
# Out:
# Overwriting suma.cpp

# %%
# !g++ suma.cpp -o suma

# %%
# !./suma
# Out:
# El promedio es: 4
